# %% [markdown]
# # **Data Source**

# %% [markdown]
# ![download.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # **Import libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pip install prophet

# %%
from prophet import Prophet

# %%
avo=pd.read_csv('avocado.csv')
avo.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %% [markdown]
# # **TSF case study**

# %%
avo.shape
# Out:
# (18249, 14)

# %%
avo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   Date          18249 non-null  object
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  object
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
# dtypes: float64(9), int64(2), object(3)
# memory usage: 1.9+ MB

# %%
avo.isnull().sum()
# Out:
# Unnamed: 0      0
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
avo.describe()
# Out:
#          Unnamed: 0  AveragePrice  Total Volume          4046          4225  \
# count  18249.000000  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04
# mean      24.232232      1.405978  8.506440e+05  2.930084e+05  2.951546e+05
# std       15.481045      0.402677  3.453545e+06  1.264989e+06  1.204120e+06
# min        0.000000      0.440000  8.456000e+01  0.000000e+00  0.000000e+00
# 25%       10.000000      1.100000  1.083858e+04  8.540700e+02  3.008780e+03
# 50%       24.000000      1.370000  1.073768e+05  8.645300e+03  2.906102e+04
# 75%       38.000000      1.660000  4.329623e+05  1.110202e+05  1.502069e+05
# max       52.000000      3.250000  6.250565e+07  2.274362e+07  2.047057e+07
#
#                4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000
# mean   2.283974e+04  2.396392e+05  1.821947e+05  5.433809e+04    3106.426507
# ...

# %%
avo=avo.sort_values("Date")

# %%
avo.head()
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046      4225  \
# 11569          51  2015-01-04          1.75      27365.89  9307.34   3844.81
# 9593           51  2015-01-04          1.49      17723.17  1189.35  15628.27
# 10009          51  2015-01-04          1.68       2896.72   161.68    206.96
# 1819           51  2015-01-04          1.52      54956.80  3013.04  35456.88
# 9333           51  2015-01-04          1.64       1505.12     1.27   1129.50
#
#           4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 11569   615.28    13598.46    13061.10      537.36          0.0       organic
# 9593      0.00      905.55      905.55        0.00          0.0       organic
# 10009     0.00     2528.08     2528.08        0.00          0.0       organic
# 1819   1561.70    14925.18    11264.80     3660.38          0.0  conventional
# 9333      0.00      374.35      186.67      187.68          0.0       organic
#
#        year              region
# ...

# %% [markdown]
# # **EDA**

# %%
plt.figure(figsize=(20,10))
plt.plot(avo['Date'],avo['AveragePrice'])
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.countplot(x='year',data=avo)
# Out:
# <Axes: xlabel='year', ylabel='count'>

# %% [markdown]
# # **pre processing**

# %%
df=avo[['Date','AveragePrice']]
df
# Out:
#              Date  AveragePrice
# 11569  2015-01-04          1.75
# 9593   2015-01-04          1.49
# 10009  2015-01-04          1.68
# 1819   2015-01-04          1.52
# 9333   2015-01-04          1.64
# ...           ...           ...
# 8574   2018-03-25          1.36
# 9018   2018-03-25          0.70
# 18141  2018-03-25          1.42
# 17673  2018-03-25          1.70
# 8814   2018-03-25          1.34
#
# [18249 rows x 2 columns]

# %%
avo_proph.columns=['ds','y']
avo_proph
# Out:
#                ds     y
# 11569  2015-01-04  1.75
# 9593   2015-01-04  1.49
# 10009  2015-01-04  1.68
# 1819   2015-01-04  1.52
# 9333   2015-01-04  1.64
# ...           ...   ...
# 8574   2018-03-25  1.36
# 9018   2018-03-25  0.70
# 18141  2018-03-25  1.42
# 17673  2018-03-25  1.70
# 8814   2018-03-25  1.34
#
# [18249 rows x 2 columns]

# %%
model=Prophet()
model.fit(avo_proph)
# Out:
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpzns5bsoj/463fcepa.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpzns5bsoj/wt64a471.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=77935', 'data', 'file=/tmp/tmpzns5bsoj/463fcepa.json', 'init=/tmp/tmpzns5bsoj/wt64a471.json', 'output', 'file=/tmp/tmpzns5bsoj/prophet_modelhnub37ch/prophet_model-20250727160002.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:00:02 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:00:08 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
future=model.make_future_dataframe(periods=365)
future
# Out:
#             ds
# 0   2015-01-04
# 1   2015-01-11
# 2   2015-01-18
# 3   2015-01-25
# 4   2015-02-01
# ..         ...
# 529 2019-03-21
# 530 2019-03-22
# 531 2019-03-23
# 532 2019-03-24
# 533 2019-03-25
#
# [534 rows x 1 columns]

# %%
forcast=model.predict(future)
forcast
# Out:
#             ds     trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 0   2015-01-04  1.501458    0.889267    1.861555     1.501458     1.501458
# 1   2015-01-11  1.496064    0.918638    1.849504     1.496064     1.496064
# 2   2015-01-18  1.490671    0.906499    1.884497     1.490671     1.490671
# 3   2015-01-25  1.485278    0.839360    1.853648     1.485278     1.485278
# 4   2015-02-01  1.479885    0.807120    1.814142     1.479885     1.479885
# ..         ...       ...         ...         ...          ...          ...
# 529 2019-03-21  1.157864    0.515813    1.637770     0.958858     1.347437
# 530 2019-03-22  1.157120    0.561065    1.626458     0.956778     1.347093
# 531 2019-03-23  1.156375    0.543895    1.594651     0.954698     1.346749
# 532 2019-03-24  1.155630    0.543501    1.587658     0.952597     1.346405
# 533 2019-03-25  1.154886    0.554781    1.610198     0.950476     1.346269
#
# ...

# %%
forcast[['ds','yhat','yhat_lower','yhat_upper']].tail()
# Out:
#             ds      yhat  yhat_lower  yhat_upper
# 529 2019-03-21  1.071793    0.515813    1.637770
# 530 2019-03-22  1.072824    0.561065    1.626458
# 531 2019-03-23  1.074129    0.543895    1.594651
# 532 2019-03-24  1.075690    0.543501    1.587658
# 533 2019-03-25  1.077479    0.554781    1.610198

# %%
fig_forcast=model.plot(forcast,xlabel='Date',ylabel='AveragePrice')

# %%
fig_com=model.plot_components(forcast)
